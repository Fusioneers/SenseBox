# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from constants import ABS_PATH
import os

logger = pd.read_csv(os.path.join(ABS_PATH, 'data', 'LOGGER00.CSV'))

sns.pairplot(logger)
plt.show()
